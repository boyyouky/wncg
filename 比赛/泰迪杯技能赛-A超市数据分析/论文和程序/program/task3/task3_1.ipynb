# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import pyecharts
import matplotlib as mpl
font2 = {'family' : 'Times New Roman',
'weight' : 'normal',
'size'   : 14,}

# %%
data = pd.read_csv("no.10.csv",encoding='utf-8')

# %%
data.head()
# Out:
#    顾客编号  大类编码 大类名称  中类编码  中类名称    小类编码  小类名称      销售日期    销售月份           商品编码  \
# 0  1177    12   蔬果  1201    蔬菜  120101    叶菜  20150129  201501  DW-1201010019
# 1  1177    20   粮油  2014   酱菜类  201403    笋类  20150129  201501  DW-2014030010
# 2  1177    12   蔬果  1202  加工豆类  120204  豆干豆皮  20150129  201501  DW-1202048059
# 3  1177    20   粮油  2014   酱菜类  201403    笋类  20150129  201501  DW-2014030007
# 4  1177    20   粮油  2009   盐/糖  200902   功能盐  20150129  201501  DW-2009020012
#
#    规格型号  商品类型  单位   销售数量  销售金额  商品单价 是否促销
# 0    散称    生鲜  千克  0.694  1.36  1.96    否
# 1   80g  一般商品   袋  1.000  1.70  1.70    否
# 2    散称    生鲜  千克  0.290  2.25  7.76    否
# 3  140g  一般商品   袋  1.000  2.30  2.30    否
# 4  400g  一般商品   袋  1.000  2.30  2.30    否

# %%
plt.figure(figsize=(15,8),dpi=80)
plt.xticks(fontsize=20,rotation=90)
plt.yticks(fontsize=20)
plt.rcParams.update({"font.size":20})
plt.plot(data['天数'],data['生鲜销售额'])
plt.plot(data['天数'],data['一般商品销售额'])
plt.title('生鲜商品和一般商品每天销售金额的折线图')
# Out:
# Text(0.5, 1.0, '生鲜商品和一般商品每天销售金额的折线图')

# %%
data_1177 = data.loc[data['顾客编号'] == 1177]

# %%
data_1177.head()
# Out:
#    顾客编号  大类编码 大类名称  中类编码  中类名称    小类编码  小类名称      销售日期    销售月份           商品编码  \
# 0  1177    12   蔬果  1201    蔬菜  120101    叶菜  20150129  201501  DW-1201010019
# 1  1177    20   粮油  2014   酱菜类  201403    笋类  20150129  201501  DW-2014030010
# 2  1177    12   蔬果  1202  加工豆类  120204  豆干豆皮  20150129  201501  DW-1202048059
# 3  1177    20   粮油  2014   酱菜类  201403    笋类  20150129  201501  DW-2014030007
# 4  1177    20   粮油  2009   盐/糖  200902   功能盐  20150129  201501  DW-2009020012
#
#    规格型号  商品类型  单位   销售数量  销售金额  商品单价 是否促销
# 0    散称    生鲜  千克  0.694  1.36  1.96    否
# 1   80g  一般商品   袋  1.000  1.70  1.70    否
# 2    散称    生鲜  千克  0.290  2.25  7.76    否
# 3  140g  一般商品   袋  1.000  2.30  2.30    否
# 4  400g  一般商品   袋  1.000  2.30  2.30    否

# %%
import matplotlib as mpl
mpl.rcParams['font.sans-serif'] = ['KaiTi']
plt.figure(figsize=(10,10))
sum1.plot(kind='bar', 
                      figsize=(12,5)
                                 )
plt.title('前十位顾客的消费金额')
# Out:
# Text(0.5, 1.0, '前十位顾客的消费金额')

# %%
data['顾客编号']==372
data_108 = data.loc[data['顾客编号']==372]
data_108.head()
groupby2 = data_108['销售金额'].groupby(data['大类名称'])
sum2 = groupby2.sum()
mpl.rcParams['font.sans-serif'] = ['KaiTi']
plt.figure(figsize=(10,10))
sum2.plot(kind='bar', 
                      figsize=(12,5)
                                 )
plt.title('372号顾客的消费情况')
# Out:
# Text(0.5, 1.0, '372号顾客的消费情况')
